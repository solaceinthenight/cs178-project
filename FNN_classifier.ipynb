# %% [markdown]
# # Importing Libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import torch
import torchvision
import torchvision.transforms as transforms
import math

from sklearn.datasets import fetch_openml
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split, ShuffleSplit, GridSearchCV
from sklearn.inspection import DecisionBoundaryDisplay
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier

# %%
# Fix the random seed for reproducibility
# !! Important !! : do not change this
seed = 1234
np.random.seed(seed)

import warnings
warnings.filterwarnings("ignore") # for future tuning

# %% [markdown]
# # Loading Data

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

batch_size = 128

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=4)

testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=4)

classes = ('plane', 'car', 'bird', 'cat',
           'deer', 'dog', 'frog', 'horse', 'ship', 'truck')
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
trainset_np = np.asarray(trainset.data)
trainset_labels = np.asarray(trainset.targets)
testset_np = np.asarray(testset.data)
testset_labels = np.asarray(testset.targets)

X_train = trainset_np
y_train = trainset_labels

validset_np = trainset_np[40000:50000]
validset_labels = trainset_labels[40000:50000]
trainset_np = trainset_np[0:40000]
trainset_labels = trainset_labels[0:40000]

print('Train Set')
print(trainset_np.shape)
print(trainset_labels.shape)
print('-')
print('Validation Set')
print(validset_np.shape)
print(validset_labels.shape)
print('-')
print('Test Set')
print(testset_np.shape)
print(testset_labels.shape)
print('-')
print(f'X_train {X_train.shape}')
print(f'y_train {y_train.shape}')
# Out:
# Train Set
# (40000, 32, 32, 3)
# (40000,)
# -
# Validation Set
# (10000, 32, 32, 3)
# (10000,)
# -
# Test Set
# (10000, 32, 32, 3)
# (10000,)
# -
# X_train (50000, 32, 32, 3)
# y_train (50000,)

# %% [markdown]
# # Flattening Data

# %%
# For use in manual tuning
trainset_flattened = np.empty((trainset_np.shape[0], 3072))
validset_flattened = np.empty((validset_np.shape[0], 3072))
testset_flattened = np.empty((testset_np.shape[0], 3072))

# For use in cross-validation
X_train_flattened = np.empty((X_train.shape[0], 3072))

# %%
for i in range(trainset_np.shape[0]):
    trainset_flattened[i] = trainset_np[i].flatten()

for i in range(validset_np.shape[0]):
    validset_flattened[i] = validset_np[i].flatten()

for i in range(testset_np.shape[0]):
    testset_flattened[i] = testset_np[i].flatten()


for i in range(X_train.shape[0]):
    X_train_flattened[i] = X_train[i].flatten()

# %% [markdown]
# # Tuning MLP
#
# ### Base Classifier with Default Parameters

# %%
clf = MLPClassifier(random_state=seed)
clf.fit(trainset_flattened, trainset_labels)
y_pred = clf.predict(validset_flattened)
num = (y_pred == validset_labels).sum() # number of correct labels
print(f' Accuracy based on Validation Set {num / len(validset_labels)}') # accuracy 
# print(clf.score(testset_flattened, testset_labels))
# Out:
#  Accuracy based on Validation Set 0.0952

# %% [markdown]
# ### Using GridSearchCV for hyperparameter tuning

# %% [markdown]
# #### 100 Datapoints

# %%
import time # for elapsed time

cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

param_grid = {
    'hidden_layer_sizes':[5, 10, 15, (5, 5), (5, 10)],
    'activation': ['identity','logistic','tanh','relu'],
    'solver': ['lbfgs','sgd','adam'],
    'learning_rate':['constant','invscaling','adaptive']
    'random_state':[seed]}

gridSearch = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
start = time.time()
gridSearch.fit(X_train_flattened[:100], y_train[:100])
print('Score: ', gridSearch.best_score_)
print('Parameters: ', gridSearch.best_params_)
end = time.time()

print(f'Elapsed Time: {end - start}')
# Out:
# Fitting 1 folds for each of 180 candidates, totalling 180 fits
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.2s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   0.2s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.8s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.7s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.9s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.7s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   1.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   1.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   1.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.1s
# Score:  0.3
# Parameters:  {'activation': 'identity', 'hidden_layer_sizes': 5, 'learning_rate': 'invscaling', 'solver': 'lbfgs'}
# Elapsed Time: 32.095014810562134

# %% [markdown]
# ##### Displaying Hyperparameter Tuning Results

# %%
results_df = pd.DataFrame(gridSearch.cv_results_)
print(results_df)
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0         0.203080           0.0         0.001004             0.0
# 1         0.014840           0.0         0.001018             0.0
# 2         0.120437           0.0         0.000000             0.0
# 3         0.276190           0.0         0.001507             0.0
# 4         0.130112           0.0         0.000000             0.0
# ..             ...           ...              ...             ...
# 175       0.017333           0.0         0.000000             0.0
# 176       0.207999           0.0         0.001012             0.0
# 177       0.026511           0.0         0.001270             0.0
# 178       0.125922           0.0         0.001002             0.0
# 179       0.194782           0.0         0.001094             0.0
#
#     param_activation param_hidden_layer_sizes param_learning_rate  \
# 0           identity                        5            constant
# 1           identity                        5            constant
# 2           identity                        5            constant
# 3           identity                        5          invscaling
# 4           identity                        5          invscaling
# ..               ...                      ...                 ...
# 175             relu                  (5, 10)          invscaling
# 176             relu                  (5, 10)          invscaling
# 177             relu                  (5, 10)            adaptive
# 178             relu                  (5, 10)            adaptive
# 179             relu                  (5, 10)            adaptive
#
#     param_solver                                             params  \
# 0          lbfgs  {'activation': 'identity', 'hidden_layer_sizes...
# 1            sgd  {'activation': 'identity', 'hidden_layer_sizes...
# 2           adam  {'activation': 'identity', 'hidden_layer_sizes...
# 3          lbfgs  {'activation': 'identity', 'hidden_layer_sizes...
# 4            sgd  {'activation': 'identity', 'hidden_layer_sizes...
# ..           ...                                                ...
# 175          sgd  {'activation': 'relu', 'hidden_layer_sizes': (...
# 176         adam  {'activation': 'relu', 'hidden_layer_sizes': (...
# 177        lbfgs  {'activation': 'relu', 'hidden_layer_sizes': (...
# 178          sgd  {'activation': 'relu', 'hidden_layer_sizes': (...
# 179         adam  {'activation': 'relu', 'hidden_layer_sizes': (...
#
#      split0_test_score  mean_test_score  std_test_score  rank_test_score
# 0                 0.15             0.15             0.0               27
# 1                 0.05             0.05             0.0              162
# 2                 0.15             0.15             0.0               27
# 3                 0.30             0.30             0.0                1
# 4                 0.15             0.15             0.0               27
# ..                 ...              ...             ...              ...
# 175               0.20             0.20             0.0                9
# 176               0.20             0.20             0.0                9
# 177               0.15             0.15             0.0               27
# 178               0.15             0.15             0.0               27
# 179               0.20             0.20             0.0                9
#
# [180 rows x 13 columns]

# %% [markdown]
# #### Variable Amount of Datapoints

# %%
vary_datapoints = [1000, 5000, 10000, 50000] # 50000 is the original total
results = {} # num_datapoint -> (gridSearch_obj, elapsed_time)

cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

param_grid = {
    'hidden_layer_sizes':[5, 10, 15, (5, 5), (5, 10)],
    'activation': ['identity','logistic','tanh','relu'],
    'solver': ['lbfgs','sgd','adam'],
    'learning_rate':['constant','invscaling','adaptive']
    'random_state':[seed]}

for num_datapoint in vary_datapoints:
    gridSearch_obj = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
    start = time.time()
    gridSearch_obj.fit(X_train_flattened[:num_datapoint], y_train[:num_datapoint])
    end = time.time()
    elapsed = end - start
    results[num_datapoint] = (gridSearch_obj, elapsed)
# Out:
# Fitting 1 folds for each of 180 candidates, totalling 180 fits
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.2s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.3s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.2s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.3s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.2s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.3s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.2s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.5s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   1.2s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   1.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   1.2s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.9s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   1.2s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   1.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   1.2s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   1.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   1.6s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.6s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.5s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.3s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   0.8s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   0.9s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   0.7s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.6s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.6s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   1.0s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.6s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   2.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.9s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   0.7s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   0.6s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   0.6s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   1.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   1.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   1.4s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   1.6s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   1.4s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   1.4s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.4s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   1.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   1.2s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   1.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.0s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   1.3s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   1.1s
# Fitting 1 folds for each of 180 candidates, totalling 180 fits
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   2.9s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   7.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   3.7s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   2.6s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   7.9s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   2.9s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   6.6s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   5.9s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   1.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   7.5s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   2.7s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   2.2s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   1.0s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   3.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   7.7s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   2.2s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.6s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   8.3s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   1.0s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   3.7s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.4s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   3.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.6s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   9.8s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   2.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   4.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=  12.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=  13.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=  12.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=  12.4s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   4.4s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=  12.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=  10.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   4.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=  12.9s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=  14.0s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   4.7s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=  12.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=  11.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   4.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=  12.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=  12.6s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.2s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   2.7s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   2.4s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   6.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.8s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   2.1s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   6.2s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   5.6s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   2.2s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   7.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   2.2s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   8.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   2.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   2.1s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   7.9s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   6.6s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   2.5s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   9.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   2.6s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   1.9s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   8.5s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   8.6s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=  16.1s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   1.9s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   7.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   4.3s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   2.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   7.4s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   1.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   2.9s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=  13.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   1.8s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=  13.7s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   1.2s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   7.4s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   1.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=  14.0s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   2.4s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   2.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   6.4s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   3.2s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   2.4s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   6.0s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   5.7s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   3.1s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   2.2s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   1.9s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.5s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   1.4s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   2.2s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.8s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   6.3s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   8.6s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   2.2s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   2.3s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   8.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   3.2s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   8.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=   5.9s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   2.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   3.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   2.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.1s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   1.0s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   5.9s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   6.4s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   6.6s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   2.3s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.4s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   1.6s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   2.4s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   5.7s
# [CV] END activation=tanh, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   1.3s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   0.2s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=   4.9s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   3.3s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   3.1s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   7.5s
# [CV] END activation=relu, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   3.3s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   3.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   6.2s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   3.8s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   1.7s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   1.0s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   4.1s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   0.6s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   9.2s
# [CV] END activation=relu, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   4.2s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   6.3s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   4.6s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   2.5s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   4.1s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   0.9s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=  10.0s
# [CV] END activation=relu, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   5.2s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=   3.3s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   3.8s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=   0.7s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=   3.3s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=   7.7s
# [CV] END activation=relu, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   3.1s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=   4.2s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=   2.4s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   0.5s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=   0.8s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=   2.5s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   0.3s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=   7.5s
# [CV] END activation=relu, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=   3.7s
# Fitting 1 folds for each of 180 candidates, totalling 180 fits
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=   7.4s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=  22.5s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=  18.4s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   7.3s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   1.5s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=  21.2s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   7.7s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=  22.3s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=  20.9s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   0.8s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=  27.4s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=  19.3s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   2.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   1.8s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=  18.1s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   2.2s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=  28.3s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=  20.7s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   0.9s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=  28.6s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=  21.4s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   9.7s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   1.9s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=  25.3s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   3.5s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=  29.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   6.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   7.7s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=  24.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=  22.3s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   0.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time=  24.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=  15.2s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=   1.9s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=  24.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=  22.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=lbfgs; total time=   7.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=sgd; total time=  24.8s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=constant, solver=adam; total time=  21.7s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=lbfgs; total time=   2.2s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=sgd; total time=  24.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=invscaling, solver=adam; total time=  13.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=lbfgs; total time=   8.1s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=sgd; total time=  24.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 10), learning_rate=adaptive, solver=adam; total time=  20.0s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=  10.6s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time=  21.5s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   2.6s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   9.9s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=   1.5s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=49.4min
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=  10.1s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   6.8s
# [CV] END activation=logistic, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   1.9s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   9.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=79.3min
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   2.5s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   0.4s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   1.7s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=   9.8s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   6.8s
# [CV] END activation=logistic, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   1.5s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=  10.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   1.8s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   8.9s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=   1.0s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   1.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=   9.4s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time=  16.3s
# [CV] END activation=logistic, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   1.2s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=   0.1s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time=  13.5s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=   1.4s
# [CV] END activation=logistic, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=   8.9s
# ...
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=   7.7s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time=  10.9s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=   2.1s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=   8.4s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time=   5.3s
# [CV] END activation=tanh, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=   4.0s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time=   1.5s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=   1.8s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time=   9.4s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time=   7.6s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=   1.7s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time=  10.6s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time=   5.9s
# [CV] END activation=tanh, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=   1.3s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time=   9.2s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time=   1.4s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=   1.2s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=   1.0s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time=  10.1s
# [CV] END activation=tanh, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   1.5s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 15
#      13 gridSearch_obj = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
#      14 start = time.time()
# ---> 15 gridSearch_obj.fit(X_train_flattened[:num_datapoint], y_train[:num_datapoint])
#      16 end = time.time()
#      17 elapsed = end - start
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~\cs178\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~\cs178\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\cs178\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\cs178\Lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_validation.py:686, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     684         estimator.fit(X_train, **fit_params)
#     685     else:
# --> 686         estimator.fit(X_train, y_train, **fit_params)
#     688 except Exception:
#     689     # Note fit time as time until error
#     690     fit_time = time.time() - start_time
#
# File ~\cs178\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:749, in BaseMultilayerPerceptron.fit(self, X, y)
#     731 """Fit the model to data matrix X and target(s) y.
#     732
#     733 Parameters
#    (...)
#     745     Returns a trained MLP model.
#     746 """
#     747 self._validate_params()
# --> 749 return self._fit(X, y, incremental=False)
#
# File ~\cs178\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:484, in BaseMultilayerPerceptron._fit(self, X, y, incremental)
#     482 # Run the LBFGS solver
#     483 elif self.solver == "lbfgs":
# --> 484     self._fit_lbfgs(
#     485         X, y, activations, deltas, coef_grads, intercept_grads, layer_units
#     486     )
#     488 # validate parameter weights
#     489 weights = chain(self.coefs_, self.intercepts_)
#
# File ~\cs178\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:528, in BaseMultilayerPerceptron._fit_lbfgs(self, X, y, activations, deltas, coef_grads, intercept_grads, layer_units)
#     525 else:
#     526     iprint = -1
# --> 528 opt_res = scipy.optimize.minimize(
#     529     self._loss_grad_lbfgs,
#     530     packed_coef_inter,
#     531     method="L-BFGS-B",
#     532     jac=True,
#     533     options={
#     534         "maxfun": self.max_fun,
#     535         "maxiter": self.max_iter,
#     536         "iprint": iprint,
#     537         "gtol": self.tol,
#     538     },
#     539     args=(X, y, activations, deltas, coef_grads, intercept_grads),
#     540 )
#     541 self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
#     542 self.loss_ = opt_res.fun
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_minimize.py:696, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     693     res = _minimize_newtoncg(fun, x0, args, jac, hess, hessp, callback,
#     694                              **options)
#     695 elif meth == 'l-bfgs-b':
# --> 696     res = _minimize_lbfgsb(fun, x0, args, jac, bounds,
#     697                            callback=callback, **options)
#     698 elif meth == 'tnc':
#     699     res = _minimize_tnc(fun, x0, args, jac, bounds, callback=callback,
#     700                         **options)
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_lbfgsb_py.py:359, in _minimize_lbfgsb(fun, x0, args, jac, bounds, disp, maxcor, ftol, gtol, eps, maxfun, maxiter, iprint, callback, maxls, finite_diff_rel_step, **unknown_options)
#     353 task_str = task.tobytes()
#     354 if task_str.startswith(b'FG'):
#     355     # The minimization routine wants f and g at the current x.
#     356     # Note that interruptions due to maxfun are postponed
#     357     # until the completion of the current minimization iteration.
#     358     # Overwrite f and g:
# --> 359     f, g = func_and_grad(x)
#     360 elif task_str.startswith(b'NEW_X'):
#     361     # new iteration
#     362     n_iterations += 1
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_differentiable_functions.py:285, in ScalarFunction.fun_and_grad(self, x)
#     283 if not np.array_equal(x, self.x):
#     284     self._update_x_impl(x)
# --> 285 self._update_fun()
#     286 self._update_grad()
#     287 return self.f, self.g
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_differentiable_functions.py:251, in ScalarFunction._update_fun(self)
#     249 def _update_fun(self):
#     250     if not self.f_updated:
# --> 251         self._update_fun_impl()
#     252         self.f_updated = True
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_differentiable_functions.py:155, in ScalarFunction.__init__.<locals>.update_fun()
#     154 def update_fun():
# --> 155     self.f = fun_wrapped(self.x)
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_differentiable_functions.py:137, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     133 self.nfev += 1
#     134 # Send a copy because the user may overwrite it.
#     135 # Overwriting results in undefined behaviour because
#     136 # fun(self.x) will change self.x, with the two no longer linked.
# --> 137 fx = fun(np.copy(x), *args)
#     138 # Make sure the function returns a true scalar
#     139 if not np.isscalar(fx):
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_optimize.py:76, in MemoizeJac.__call__(self, x, *args)
#      74 def __call__(self, x, *args):
#      75     """ returns the function value """
# ---> 76     self._compute_if_needed(x, *args)
#      77     return self._value
#
# File ~\cs178\Lib\site-packages\scipy\optimize\_optimize.py:70, in MemoizeJac._compute_if_needed(self, x, *args)
#      68 if not np.all(x == self.x) or self._value is None or self.jac is None:
#      69     self.x = np.asarray(x).copy()
# ---> 70     fg = self.fun(x, *args)
#      71     self.jac = fg[1]
#      72     self._value = fg[0]
#
# File ~\cs178\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:277, in BaseMultilayerPerceptron._loss_grad_lbfgs(self, packed_coef_inter, X, y, activations, deltas, coef_grads, intercept_grads)
#     236 """Compute the MLP loss function and its corresponding derivatives
#     237 with respect to the different parameters given in the initialization.
#     238
#    (...)
#     274 grad : array-like, shape (number of nodes of all layers,)
#     275 """
#     276 self._unpack(packed_coef_inter)
# --> 277 loss, coef_grads, intercept_grads = self._backprop(
#     278     X, y, activations, deltas, coef_grads, intercept_grads
#     279 )
#     280 grad = _pack(coef_grads, intercept_grads)
#     281 return loss, grad
#
# File ~\cs178\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:356, in BaseMultilayerPerceptron._backprop(self, X, y, activations, deltas, coef_grads, intercept_grads)
#     353     deltas[i - 1] = safe_sparse_dot(deltas[i], self.coefs_[i].T)
#     354     inplace_derivative(activations[i], deltas[i - 1])
# --> 356     self._compute_loss_grad(
#     357         i - 1, n_samples, activations, deltas, coef_grads, intercept_grads
#     358     )
#     360 return loss, coef_grads, intercept_grads
#
# File ~\cs178\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:227, in BaseMultilayerPerceptron._compute_loss_grad(self, layer, n_samples, activations, deltas, coef_grads, intercept_grads)
#     219 def _compute_loss_grad(
#     220     self, layer, n_samples, activations, deltas, coef_grads, intercept_grads
#     221 ):
#     222     """Compute the gradient of loss with respect to coefs and intercept for
#     223     specified layer.
#     224
#     225     This function does backpropagation for the specified one layer.
#     226     """
# --> 227     coef_grads[layer] = safe_sparse_dot(activations[layer].T, deltas[layer])
#     228     coef_grads[layer] += self.alpha * self.coefs_[layer]
#     229     coef_grads[layer] /= n_samples
#
# File ~\cs178\Lib\site-packages\sklearn\utils\extmath.py:192, in safe_sparse_dot(a, b, dense_output)
#     188 else:
#     189     ret = a @ b
#     191 if (
# --> 192     sparse.issparse(a)
#     193     and sparse.issparse(b)
#     194     and dense_output
#     195     and hasattr(ret, "toarray")
#     196 ):
#     197     return ret.toarray()
#     198 return ret
#
# File ~\cs178\Lib\site-packages\scipy\sparse\_base.py:1301, in isspmatrix(x)
#    1297         else:
#    1298             return np.zeros(self.shape, dtype=self.dtype, order=order)
# -> 1301 def isspmatrix(x):
#    1302     """Is x of a sparse matrix type?
#    1303
#    1304     Parameters
#    (...)
#    1326     False
#    1327     """
#    1328     return isinstance(x, spmatrix)
#
# KeyboardInterrupt:

# %% [markdown]
# Individual Additions to `results` dictionary.

# %%
num_datapoint = 10000
cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

gridSearch_obj = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
start = time.time()
gridSearch_obj.fit(X_train_flattened[:num_datapoint], y_train[:num_datapoint])
end = time.time()
elapsed = end - start
results[num_datapoint] = (gridSearch_obj, elapsed)

# %%
num_datapoint = 50000
cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

gridSearch_obj = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
start = time.time()
gridSearch_obj.fit(X_train_flattened[:num_datapoint], y_train[:num_datapoint])
end = time.time()
elapsed = end - start
results[num_datapoint] = (gridSearch_obj, elapsed)
# Out:
# Fitting 1 folds for each of 180 candidates, totalling 180 fits
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=lbfgs; total time=  57.2s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=sgd; total time= 2.2min
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=constant, solver=adam; total time=  41.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=lbfgs; total time=  46.2s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=sgd; total time= 2.1min
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=  31.3s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=lbfgs; total time=  47.4s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=sgd; total time= 2.1min
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=  33.2s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=lbfgs; total time=  16.8s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=constant, solver=adam; total time=  40.4s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=lbfgs; total time= 1.0min
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=sgd; total time= 2.6min
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=invscaling, solver=adam; total time=  40.9s
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=lbfgs; total time= 1.0min
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=sgd; total time= 2.4min
# [CV] END activation=identity, hidden_layer_sizes=10, learning_rate=adaptive, solver=adam; total time=  41.6s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=lbfgs; total time= 1.3min
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=sgd; total time= 2.5min
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=constant, solver=adam; total time=  36.7s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=lbfgs; total time=  16.9s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=sgd; total time= 2.5min
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=  38.9s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=lbfgs; total time=  14.1s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=sgd; total time= 2.5min
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=  41.6s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=lbfgs; total time=  47.7s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=sgd; total time= 2.1min
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=constant, solver=adam; total time=  42.9s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=lbfgs; total time=  48.5s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=sgd; total time= 2.0min
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=invscaling, solver=adam; total time=  55.4s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=lbfgs; total time=  52.4s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=sgd; total time=  59.7s
# [CV] END activation=identity, hidden_layer_sizes=(5, 5), learning_rate=adaptive, solver=adam; total time=   4.4s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[30], line 6
#       4 gridSearch_obj = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
#       5 start = time.time()
# ----> 6 gridSearch_obj.fit(X_train_flattened[:num_datapoint], y_train[:num_datapoint])
#       7 end = time.time()
#       8 elapsed = end - start
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_search.py:874, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     868     results = self._format_results(
#     869         all_candidate_params, n_splits, all_out, all_more_results
#     870     )
#     872     return results
# --> 874 self._run_search(evaluate_candidates)
#     876 # multimetric is determined here because in the case of a callable
#     877 # self.scoring the return type is only known after calling
#     878 first_test_score = all_out[0]["test_scores"]
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_search.py:1388, in GridSearchCV._run_search(self, evaluate_candidates)
#    1386 def _run_search(self, evaluate_candidates):
#    1387     """Search all candidates in param_grid"""
# -> 1388     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_search.py:821, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     813 if self.verbose > 0:
#     814     print(
#     815         "Fitting {0} folds for each of {1} candidates,"
#     816         " totalling {2} fits".format(
#     817             n_splits, n_candidates, n_candidates * n_splits
#     818         )
#     819     )
# --> 821 out = parallel(
#     822     delayed(_fit_and_score)(
#     823         clone(base_estimator),
#     824         X,
#     825         y,
#     826         train=train,
#     827         test=test,
#     828         parameters=parameters,
#     829         split_progress=(split_idx, n_splits),
#     830         candidate_progress=(cand_idx, n_candidates),
#     831         **fit_and_score_kwargs,
#     832     )
#     833     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     834         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     835     )
#     836 )
#     838 if len(out) < 1:
#     839     raise ValueError(
#     840         "No fits were performed. "
#     841         "Was the CV iterator empty? "
#     842         "Were there no candidates?"
#     843     )
#
# File ~\cs178\Lib\site-packages\sklearn\utils\parallel.py:63, in Parallel.__call__(self, iterable)
#      58 config = get_config()
#      59 iterable_with_config = (
#      60     (_with_config(delayed_func, config), args, kwargs)
#      61     for delayed_func, args, kwargs in iterable
#      62 )
# ---> 63 return super().__call__(iterable_with_config)
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:1088, in Parallel.__call__(self, iterable)
#    1085 if self.dispatch_one_batch(iterator):
#    1086     self._iterating = self._original_iterator is not None
# -> 1088 while self.dispatch_one_batch(iterator):
#    1089     pass
#    1091 if pre_dispatch == "all" or n_jobs == 1:
#    1092     # The iterable was consumed all at once by the above for loop.
#    1093     # No need to wait for async callbacks to trigger to
#    1094     # consumption.
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:901, in Parallel.dispatch_one_batch(self, iterator)
#     899     return False
#     900 else:
# --> 901     self._dispatch(tasks)
#     902     return True
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:819, in Parallel._dispatch(self, batch)
#     817 with self._lock:
#     818     job_idx = len(self._jobs)
# --> 819     job = self._backend.apply_async(batch, callback=cb)
#     820     # A job can complete so quickly than its callback is
#     821     # called before we get here, causing self._jobs to
#     822     # grow. To ensure correct results ordering, .insert is
#     823     # used (rather than .append) in the following line
#     824     self._jobs.insert(job_idx, job)
#
# File ~\cs178\Lib\site-packages\joblib\_parallel_backends.py:208, in SequentialBackend.apply_async(self, func, callback)
#     206 def apply_async(self, func, callback=None):
#     207     """Schedule a func to be run"""
# --> 208     result = ImmediateResult(func)
#     209     if callback:
#     210         callback(result)
#
# File ~\cs178\Lib\site-packages\joblib\_parallel_backends.py:597, in ImmediateResult.__init__(self, batch)
#     594 def __init__(self, batch):
#     595     # Don't delay the application, to avoid keeping the input
#     596     # arguments in memory
# --> 597     self.results = batch()
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:288, in BatchedCalls.__call__(self)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\cs178\Lib\site-packages\joblib\parallel.py:288, in <listcomp>(.0)
#     284 def __call__(self):
#     285     # Set the default nested backend to self._backend but do not set the
#     286     # change the default number of processes to -1
#     287     with parallel_backend(self._backend, n_jobs=self._n_jobs):
# --> 288         return [func(*args, **kwargs)
#     289                 for func, args, kwargs in self.items]
#
# File ~\cs178\Lib\site-packages\sklearn\utils\parallel.py:123, in _FuncWrapper.__call__(self, *args, **kwargs)
#     121     config = {}
#     122 with config_context(**config):
# --> 123     return self.function(*args, **kwargs)
#
# File ~\cs178\Lib\site-packages\sklearn\model_selection\_validation.py:678, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     674     estimator = estimator.set_params(**cloned_parameters)
#     676 start_time = time.time()
# --> 678 X_train, y_train = _safe_split(estimator, X, y, train)
#     679 X_test, y_test = _safe_split(estimator, X, y, test, train)
#     681 result = {}
#
# File ~\cs178\Lib\site-packages\sklearn\utils\metaestimators.py:236, in _safe_split(estimator, X, y, indices, train_indices)
#     233     X_subset = _safe_indexing(X, indices)
#     235 if y is not None:
# --> 236     y_subset = _safe_indexing(y, indices)
#     237 else:
#     238     y_subset = None
#
# File ~\cs178\Lib\site-packages\sklearn\utils\__init__.py:285, in _safe_indexing(X, indices, axis)
#     281             raise ValueError(err_msg)
#     282     raise ValueError(err_msg)
# --> 285 def _safe_indexing(X, indices, *, axis=0):
#     286     """Return rows, items or columns of X using indices.
#     287
#     288     .. warning::
#    (...)
#     324     not supported.
#     325     """
#     326     if indices is None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Consolidating Data

# %%
for num_datapoints, value in results.items():
    print(f'For {num_datapoints} datapoints:')
    print(f'Accuracy: {value[0].best_score_}')
    print(f'was achieved in {value[1]} seconds with the following parameters:')
    print(f'{value[0].best_params_}')
# Out:
# For 1000 datapoints:
# Accuracy: 0.255
# was achieved in 116.40941214561462 seconds with the following parameters:
# {'activation': 'identity', 'hidden_layer_sizes': 15, 'learning_rate': 'adaptive', 'solver': 'adam'}
# For 5000 datapoints:
# Accuracy: 0.322
# was achieved in 777.1471126079559 seconds with the following parameters:
# {'activation': 'identity', 'hidden_layer_sizes': (5, 10), 'learning_rate': 'adaptive', 'solver': 'adam'}
# For 10000 datapoints:
# Accuracy: 0.362
# was achieved in 1749.1434381008148 seconds with the following parameters:
# {'activation': 'identity', 'hidden_layer_sizes': 10, 'learning_rate': 'invscaling', 'solver': 'adam'}

# %% [markdown]
# ### Hyperparameter Tuning (Part 2)
# Now we should consider using different hidden layer sizes paired with two types of learning rates.

# %%
num_datapoint = 5000

cv = ShuffleSplit(n_splits=1, test_size=0.2, random_state=seed)

param_grid = {
    'hidden_layer_sizes':range(1, 100, 2),
    'activation': ['identity'],
    'solver': ['adam'],
    'learning_rate':['invscaling','adaptive'],
    'random_state':[seed]}


grid_search = GridSearchCV(MLPClassifier(), param_grid, cv=cv,verbose=2)
start = time.time()
grid_search.fit(X_train_flattened[:num_datapoint], y_train[:num_datapoint])
end = time.time()
elapsed = end - start
print(f'Elapsed Time: {elapsed}')
# Out:
# Fitting 1 folds for each of 100 candidates, totalling 100 fits
# [CV] END activation=identity, hidden_layer_sizes=1, learning_rate=invscaling, solver=adam; total time=   7.1s
# [CV] END activation=identity, hidden_layer_sizes=1, learning_rate=adaptive, solver=adam; total time=   8.2s
# [CV] END activation=identity, hidden_layer_sizes=3, learning_rate=invscaling, solver=adam; total time=  10.7s
# [CV] END activation=identity, hidden_layer_sizes=3, learning_rate=adaptive, solver=adam; total time=  10.8s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=invscaling, solver=adam; total time=  13.0s
# [CV] END activation=identity, hidden_layer_sizes=5, learning_rate=adaptive, solver=adam; total time=   4.4s
# [CV] END activation=identity, hidden_layer_sizes=7, learning_rate=invscaling, solver=adam; total time=   5.9s
# [CV] END activation=identity, hidden_layer_sizes=7, learning_rate=adaptive, solver=adam; total time=   9.4s
# [CV] END activation=identity, hidden_layer_sizes=9, learning_rate=invscaling, solver=adam; total time=   3.5s
# [CV] END activation=identity, hidden_layer_sizes=9, learning_rate=adaptive, solver=adam; total time=   5.1s
# [CV] END activation=identity, hidden_layer_sizes=11, learning_rate=invscaling, solver=adam; total time=   9.3s
# [CV] END activation=identity, hidden_layer_sizes=11, learning_rate=adaptive, solver=adam; total time=   4.6s
# [CV] END activation=identity, hidden_layer_sizes=13, learning_rate=invscaling, solver=adam; total time=   6.5s
# [CV] END activation=identity, hidden_layer_sizes=13, learning_rate=adaptive, solver=adam; total time=   2.8s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=invscaling, solver=adam; total time=   3.2s
# [CV] END activation=identity, hidden_layer_sizes=15, learning_rate=adaptive, solver=adam; total time=   4.6s
# [CV] END activation=identity, hidden_layer_sizes=17, learning_rate=invscaling, solver=adam; total time=   5.7s
# [CV] END activation=identity, hidden_layer_sizes=17, learning_rate=adaptive, solver=adam; total time=   3.9s
# [CV] END activation=identity, hidden_layer_sizes=19, learning_rate=invscaling, solver=adam; total time=   3.9s
# [CV] END activation=identity, hidden_layer_sizes=19, learning_rate=adaptive, solver=adam; total time=   3.5s
# [CV] END activation=identity, hidden_layer_sizes=21, learning_rate=invscaling, solver=adam; total time=   5.9s
# [CV] END activation=identity, hidden_layer_sizes=21, learning_rate=adaptive, solver=adam; total time=   6.1s
# [CV] END activation=identity, hidden_layer_sizes=23, learning_rate=invscaling, solver=adam; total time=   7.9s
# [CV] END activation=identity, hidden_layer_sizes=23, learning_rate=adaptive, solver=adam; total time=   7.3s
# [CV] END activation=identity, hidden_layer_sizes=25, learning_rate=invscaling, solver=adam; total time=   7.4s
# [CV] END activation=identity, hidden_layer_sizes=25, learning_rate=adaptive, solver=adam; total time=   8.2s
# [CV] END activation=identity, hidden_layer_sizes=27, learning_rate=invscaling, solver=adam; total time=   2.6s
# [CV] END activation=identity, hidden_layer_sizes=27, learning_rate=adaptive, solver=adam; total time=   4.3s
# [CV] END activation=identity, hidden_layer_sizes=29, learning_rate=invscaling, solver=adam; total time=   8.3s
# [CV] END activation=identity, hidden_layer_sizes=29, learning_rate=adaptive, solver=adam; total time=   4.7s
# [CV] END activation=identity, hidden_layer_sizes=31, learning_rate=invscaling, solver=adam; total time=   2.5s
# [CV] END activation=identity, hidden_layer_sizes=31, learning_rate=adaptive, solver=adam; total time=   6.3s
# [CV] END activation=identity, hidden_layer_sizes=33, learning_rate=invscaling, solver=adam; total time=   8.7s
# [CV] END activation=identity, hidden_layer_sizes=33, learning_rate=adaptive, solver=adam; total time=  15.2s
# [CV] END activation=identity, hidden_layer_sizes=35, learning_rate=invscaling, solver=adam; total time=   4.9s
# [CV] END activation=identity, hidden_layer_sizes=35, learning_rate=adaptive, solver=adam; total time=   2.8s
# [CV] END activation=identity, hidden_layer_sizes=37, learning_rate=invscaling, solver=adam; total time=  12.4s
# [CV] END activation=identity, hidden_layer_sizes=37, learning_rate=adaptive, solver=adam; total time=   9.0s
# [CV] END activation=identity, hidden_layer_sizes=39, learning_rate=invscaling, solver=adam; total time=   5.7s
# [CV] END activation=identity, hidden_layer_sizes=39, learning_rate=adaptive, solver=adam; total time=   7.7s
# [CV] END activation=identity, hidden_layer_sizes=41, learning_rate=invscaling, solver=adam; total time=   4.7s
# [CV] END activation=identity, hidden_layer_sizes=41, learning_rate=adaptive, solver=adam; total time=   5.8s
# [CV] END activation=identity, hidden_layer_sizes=43, learning_rate=invscaling, solver=adam; total time=   8.2s
# [CV] END activation=identity, hidden_layer_sizes=43, learning_rate=adaptive, solver=adam; total time=   8.4s
# [CV] END activation=identity, hidden_layer_sizes=45, learning_rate=invscaling, solver=adam; total time=   5.9s
# [CV] END activation=identity, hidden_layer_sizes=45, learning_rate=adaptive, solver=adam; total time=   8.3s
# [CV] END activation=identity, hidden_layer_sizes=47, learning_rate=invscaling, solver=adam; total time=  16.2s
# [CV] END activation=identity, hidden_layer_sizes=47, learning_rate=adaptive, solver=adam; total time=   7.9s
# [CV] END activation=identity, hidden_layer_sizes=49, learning_rate=invscaling, solver=adam; total time=   7.4s
# [CV] END activation=identity, hidden_layer_sizes=49, learning_rate=adaptive, solver=adam; total time=   8.0s
# [CV] END activation=identity, hidden_layer_sizes=51, learning_rate=invscaling, solver=adam; total time=   9.3s
# [CV] END activation=identity, hidden_layer_sizes=51, learning_rate=adaptive, solver=adam; total time=  10.3s
# [CV] END activation=identity, hidden_layer_sizes=53, learning_rate=invscaling, solver=adam; total time=   5.8s
# [CV] END activation=identity, hidden_layer_sizes=53, learning_rate=adaptive, solver=adam; total time=  10.1s
# [CV] END activation=identity, hidden_layer_sizes=55, learning_rate=invscaling, solver=adam; total time=   9.6s
# [CV] END activation=identity, hidden_layer_sizes=55, learning_rate=adaptive, solver=adam; total time=   9.3s
# [CV] END activation=identity, hidden_layer_sizes=57, learning_rate=invscaling, solver=adam; total time=  13.4s
# [CV] END activation=identity, hidden_layer_sizes=57, learning_rate=adaptive, solver=adam; total time=   9.1s
# [CV] END activation=identity, hidden_layer_sizes=59, learning_rate=invscaling, solver=adam; total time=   3.5s
# [CV] END activation=identity, hidden_layer_sizes=59, learning_rate=adaptive, solver=adam; total time=  10.9s
# [CV] END activation=identity, hidden_layer_sizes=61, learning_rate=invscaling, solver=adam; total time=   7.6s
# [CV] END activation=identity, hidden_layer_sizes=61, learning_rate=adaptive, solver=adam; total time=   7.0s
# [CV] END activation=identity, hidden_layer_sizes=63, learning_rate=invscaling, solver=adam; total time=   9.8s
# [CV] END activation=identity, hidden_layer_sizes=63, learning_rate=adaptive, solver=adam; total time=  11.9s
# [CV] END activation=identity, hidden_layer_sizes=65, learning_rate=invscaling, solver=adam; total time=  12.6s
# [CV] END activation=identity, hidden_layer_sizes=65, learning_rate=adaptive, solver=adam; total time=   6.9s
# [CV] END activation=identity, hidden_layer_sizes=67, learning_rate=invscaling, solver=adam; total time=  11.2s
# [CV] END activation=identity, hidden_layer_sizes=67, learning_rate=adaptive, solver=adam; total time=  25.7s
# [CV] END activation=identity, hidden_layer_sizes=69, learning_rate=invscaling, solver=adam; total time=  15.0s
# [CV] END activation=identity, hidden_layer_sizes=69, learning_rate=adaptive, solver=adam; total time=  10.5s
# [CV] END activation=identity, hidden_layer_sizes=71, learning_rate=invscaling, solver=adam; total time=   8.5s
# [CV] END activation=identity, hidden_layer_sizes=71, learning_rate=adaptive, solver=adam; total time=   8.4s
# [CV] END activation=identity, hidden_layer_sizes=73, learning_rate=invscaling, solver=adam; total time=  12.9s
# [CV] END activation=identity, hidden_layer_sizes=73, learning_rate=adaptive, solver=adam; total time=  33.4s
# [CV] END activation=identity, hidden_layer_sizes=75, learning_rate=invscaling, solver=adam; total time=   9.4s
# [CV] END activation=identity, hidden_layer_sizes=75, learning_rate=adaptive, solver=adam; total time=  12.2s
# [CV] END activation=identity, hidden_layer_sizes=77, learning_rate=invscaling, solver=adam; total time=   8.5s
# [CV] END activation=identity, hidden_layer_sizes=77, learning_rate=adaptive, solver=adam; total time=  13.8s
# [CV] END activation=identity, hidden_layer_sizes=79, learning_rate=invscaling, solver=adam; total time=  20.4s
# [CV] END activation=identity, hidden_layer_sizes=79, learning_rate=adaptive, solver=adam; total time=  18.3s
# [CV] END activation=identity, hidden_layer_sizes=81, learning_rate=invscaling, solver=adam; total time=   9.1s
# [CV] END activation=identity, hidden_layer_sizes=81, learning_rate=adaptive, solver=adam; total time=   5.1s
# [CV] END activation=identity, hidden_layer_sizes=83, learning_rate=invscaling, solver=adam; total time=  18.4s
# [CV] END activation=identity, hidden_layer_sizes=83, learning_rate=adaptive, solver=adam; total time=  19.2s
# [CV] END activation=identity, hidden_layer_sizes=85, learning_rate=invscaling, solver=adam; total time=   9.0s
# [CV] END activation=identity, hidden_layer_sizes=85, learning_rate=adaptive, solver=adam; total time=  12.9s
# [CV] END activation=identity, hidden_layer_sizes=87, learning_rate=invscaling, solver=adam; total time=  14.9s
# [CV] END activation=identity, hidden_layer_sizes=87, learning_rate=adaptive, solver=adam; total time=   5.7s
# [CV] END activation=identity, hidden_layer_sizes=89, learning_rate=invscaling, solver=adam; total time=  11.0s
# [CV] END activation=identity, hidden_layer_sizes=89, learning_rate=adaptive, solver=adam; total time=  21.4s
# [CV] END activation=identity, hidden_layer_sizes=91, learning_rate=invscaling, solver=adam; total time=  11.5s
# [CV] END activation=identity, hidden_layer_sizes=91, learning_rate=adaptive, solver=adam; total time=   8.9s
# [CV] END activation=identity, hidden_layer_sizes=93, learning_rate=invscaling, solver=adam; total time=  10.7s
# [CV] END activation=identity, hidden_layer_sizes=93, learning_rate=adaptive, solver=adam; total time=   6.1s
# [CV] END activation=identity, hidden_layer_sizes=95, learning_rate=invscaling, solver=adam; total time=  11.0s
# [CV] END activation=identity, hidden_layer_sizes=95, learning_rate=adaptive, solver=adam; total time=  18.0s
# [CV] END activation=identity, hidden_layer_sizes=97, learning_rate=invscaling, solver=adam; total time=  10.1s
# [CV] END activation=identity, hidden_layer_sizes=97, learning_rate=adaptive, solver=adam; total time=  15.0s
# [CV] END activation=identity, hidden_layer_sizes=99, learning_rate=invscaling, solver=adam; total time=   8.5s
# [CV] END activation=identity, hidden_layer_sizes=99, learning_rate=adaptive, solver=adam; total time=   7.4s
# Elapsed Time: 958.3015356063843

# %%
# Results:

print(f'For {num_datapoints} datapoints:')
print(f'Accuracy: {grid_search.best_score_}')
print(f'was achieved in {elapsed} seconds with the following parameters:')
print(f'{grid_search.best_params_}')
# Out:
# For 10000 datapoints:
# Accuracy: 0.323
# was achieved in 958.3015356063843 seconds with the following parameters:
# {'activation': 'identity', 'hidden_layer_sizes': 3, 'learning_rate': 'adaptive', 'solver': 'adam'}

# %% [markdown]
# # Final Model

# %%
clf = MLPClassifier(activation='identity', solver='adam', hidden_layer_sizes=3, learning_rate='adaptive', random_state=seed)

clf.fit(trainset_flattened, trainset_labels)

print(f' Training Set Accuracy: {clf.score(trainset_flattened, trainset_labels)}')
print(f' Validation Set Accuracy: {clf.score(validset_flattened, validset_labels)}')
print(f' Testing Set Accuracy: {clf.score(testset_flattened, testset_labels)}')
# Out:
#  Training Set Accuracy: 0.321375
#  Validation Set Accuracy: 0.3112
#  Testing Set Accuracy: 0.3031

# %% [markdown]
# ### Random Manual Tuning (Initial)
#
# The following classifiers were built to guage parameters with random values.

# %%
clf = MLPClassifier(solver='sgd', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=seed, learning_rate='adaptive')

clf.fit(trainset_flattened, trainset_labels)

y_pred = clf.predict(testset_flattened)
print(clf.score(testset_flattened, testset_labels))

# %%
clf = MLPClassifier(solver='sgd', alpha=1e-5, random_state=seed, learning_rate='adaptive')

clf.fit(trainset_flattened, trainset_labels)

# y_pred = clf.predict(testset_flattened)
print(clf.score(testset_flattened, testset_labels))

# %%
clf = MLPClassifier(solver='sgd', alpha=1e-5, hidden_layer_sizes=(5, 2), random_state=seed)

clf.fit(trainset_flattened, trainset_labels)

# y_pred = clf.predict(testset_flattened)
print(clf.score(testset_flattened, testset_labels))
